# %%
import os

dataset_path = "/kaggle/input/datasets/jainam2511j/pneumonia/chest_xray/chest_xray"

print(os.listdir(dataset_path))
# Out:
# ['val', 'test', 'train']

# %%
import os
import random
import time
import cv2
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
normal_path = "/kaggle/input/datasets/jainam2511j/pneumonia/chest_xray/chest_xray/train/NORMAL"
pneumonia_path = "/kaggle/input/datasets/jainam2511j/pneumonia/chest_xray/chest_xray/train/PNEUMONIA"

normal_count = len(os.listdir(normal_path))
pneumonia_count = len(os.listdir(pneumonia_path))

print("NORMAL Images     :", normal_count)
print("PNEUMONIA Images  :", pneumonia_count)
print("TOTAL Images      :", normal_count + pneumonia_count)
# Out:
# NORMAL Images     : 1341
# PNEUMONIA Images  : 3875
# TOTAL Images      : 5216

# %%
def load_dataset(sample_size, img_size=128):

    normal_images_needed = sample_size // 2
    pneumonia_images_needed = sample_size // 2

    selected_normal = random.sample(
        os.listdir(normal_path),
        normal_images_needed
    )

    selected_pneumonia = random.sample(
        os.listdir(pneumonia_path),
        pneumonia_images_needed
    )

    X = []
    y = []

    # NORMAL = 0
    for img_name in selected_normal:

        img_path = os.path.join(normal_path, img_name)

        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (img_size, img_size))

        X.append(img.flatten())
        y.append(0)

    # PNEUMONIA = 1
    for img_name in selected_pneumonia:

        img_path = os.path.join(pneumonia_path, img_name)

        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (img_size, img_size))

        X.append(img.flatten())
        y.append(1)

    return np.array(X), np.array(y)

print("Function created successfully!")
# Out:
# Function created successfully!

# %%
X, y = load_dataset(50)

print("X Shape :", X.shape)
print("y Shape :", y.shape)
# Out:
# X Shape : (50, 16384)
# y Shape : (50,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Samples :", len(X_train))
print("Testing Samples  :", len(X_test))
# Out:
# Training Samples : 40
# Testing Samples  : 10

# %%
start_time = time.time()

lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train, y_train)

lr_time = time.time() - start_time

y_pred_lr = lr_model.predict(X_test)

lr_accuracy = accuracy_score(y_test, y_pred_lr)

print("Accuracy :", round(lr_accuracy*100,2), "%")
print("Training Time :", round(lr_time,4), "seconds")
# Out:
# Accuracy : 100.0 %
# Training Time : 1.7821 seconds

# %%
start_time = time.time()

svm_model = SVC()

svm_model.fit(X_train, y_train)

svm_time = time.time() - start_time

y_pred_svm = svm_model.predict(X_test)

svm_accuracy = accuracy_score(y_test, y_pred_svm)

print("Accuracy :", round(svm_accuracy*100,2), "%")
print("Training Time :", round(svm_time,4), "seconds")
# Out:
# Accuracy : 80.0 %
# Training Time : 0.2687 seconds

# %%
start_time = time.time()

rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)

rf_time = time.time() - start_time

y_pred_rf = rf_model.predict(X_test)

rf_accuracy = accuracy_score(y_test, y_pred_rf)

print("Accuracy :", round(rf_accuracy*100,2), "%")
print("Training Time :", round(rf_time,4), "seconds")
# Out:
# Accuracy : 80.0 %
# Training Time : 0.162 seconds

# %%
X, y = load_dataset(500)

print("X Shape :", X.shape)
print("y Shape :", y.shape)
# Out:
# X Shape : (500, 16384)
# y Shape : (500,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Samples :", len(X_train))
print("Testing Samples  :", len(X_test))
# Out:
# Training Samples : 400
# Testing Samples  : 100

# %%
start_time = time.time()

lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train, y_train)

lr_time = time.time() - start_time

y_pred_lr = lr_model.predict(X_test)

lr_accuracy = accuracy_score(y_test, y_pred_lr)

print("Accuracy :", round(lr_accuracy*100,2), "%")
print("Training Time :", round(lr_time,4), "seconds")
# Out:
# Accuracy : 96.0 %
# Training Time : 2.7609 seconds

# %%
start_time = time.time()

svm_model = SVC()

svm_model.fit(X_train, y_train)

svm_time = time.time() - start_time

y_pred_svm = svm_model.predict(X_test)

svm_accuracy = accuracy_score(y_test, y_pred_svm)

print("Accuracy :", round(svm_accuracy*100,2), "%")
print("Training Time :", round(svm_time,4), "seconds")
# Out:
# Accuracy : 97.0 %
# Training Time : 0.3854 seconds

# %%
start_time = time.time()

rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)

rf_time = time.time() - start_time

y_pred_rf = rf_model.predict(X_test)

rf_accuracy = accuracy_score(y_test, y_pred_rf)

print("Accuracy :", round(rf_accuracy*100,2), "%")
print("Training Time :", round(rf_time,4), "seconds")
# Out:
# Accuracy : 93.0 %
# Training Time : 1.8529 seconds

# %%
X, y = load_dataset(1000)

print("X Shape :", X.shape)
print("y Shape :", y.shape)
# Out:
# X Shape : (1000, 16384)
# y Shape : (1000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Samples :", len(X_train))
print("Testing Samples  :", len(X_test))
# Out:
# Training Samples : 800
# Testing Samples  : 200

# %%
start_time = time.time()

lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train, y_train)

lr_time = time.time() - start_time

y_pred_lr = lr_model.predict(X_test)

lr_accuracy = accuracy_score(y_test, y_pred_lr)

print("Accuracy :", round(lr_accuracy*100,2), "%")
print("Training Time :", round(lr_time,4), "seconds")
# Out:
# Accuracy : 94.5 %
# Training Time : 2.3298 seconds

# %%
start_time = time.time()

svm_model = SVC()

svm_model.fit(X_train, y_train)

svm_time = time.time() - start_time

y_pred_svm = svm_model.predict(X_test)

svm_accuracy = accuracy_score(y_test, y_pred_svm)

print("Accuracy :", round(svm_accuracy*100,2), "%")
print("Training Time :", round(svm_time,4), "seconds")
# Out:
# Accuracy : 96.5 %
# Training Time : 1.4335 seconds

# %%
start_time = time.time()

rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)

rf_time = time.time() - start_time

y_pred_rf = rf_model.predict(X_test)

rf_accuracy = accuracy_score(y_test, y_pred_rf)

print("Accuracy :", round(rf_accuracy*100,2), "%")
print("Training Time :", round(rf_time,4), "seconds")
# Out:
# Accuracy : 92.0 %
# Training Time : 4.7877 seconds
